# %% [markdown]
# <a href="https://colab.research.google.com/github/Encuva/TIL/blob/main/challenge2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install torchaudio
# !pip install torchaudio==0.7.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torchaudio==0.7.0
#   Downloading https://files.pythonhosted.org/packages/5d/75/5ce994c76cf7b53ff8c577d7a8221fa0c9dfe9e34c0536c6eaf3e466788a/torchaudio-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (7.6MB)
#      |████████████████████████████████| 7.6MB 25.1MB/s
# Collecting torch==1.7.0
#   Downloading https://download.pytorch.org/whl/cu92/torch-1.7.0%2Bcu92-cp37-cp37m-linux_x86_64.whl (577.3MB)
#      |████████████████████████████████| 577.3MB 30kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->torchaudio==0.7.0) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->torchaudio==0.7.0) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->torchaudio==0.7.0) (1.19.5)
# Collecting dataclasses
#   Downloading https://files.pythonhosted.org/packages/26/2f/1095cdc2868052dd1e64520f7c0d5c8c550ad297e944e641dbf1ffbb9a5d/dataclasses-0.6-py3-none-any.whl
# ERROR: torchvision 0.10.0+cu102 has requirement torch==1.9.0, but you'll have torch 1.7.0+cu92 which is incompatible.
# ERROR: torchtext 0.10.0 has requirement torch==1.9.0, but you'll have torch 1.7.0+cu92 which is incompatible.
# Installing collected packages: dataclasses, torch, torchaudio
#   Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
# Successfully installed dataclasses-0.6 torch-1.7.0+cu92 torchaudio-0.7.0

# %%
import os
import numpy as np
import pandas as pd

# %%
# current torch version is 1.7.0+cu101
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import warnings
warnings.filterwarnings("ignore")
import torchaudio

import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"
# Out:
# cuda

# %% [markdown]
# ## Speech Classification Dataset
# We will be providing the base dataset that will be used for the first task of the Speech Classification competition.

# %%
# !gdown --id 1im5shxcavdoTRNT66mhVdtA_E0ZR8QLl
# !unzip s1_train_release.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1im5shxcavdoTRNT66mhVdtA_E0ZR8QLl
# To: /content/s1_train_release.zip
# 48.3MB [00:00, 67.5MB/s]
# Archive:  s1_train_release.zip
#    creating: s1_train_release/bird/
#   inflating: s1_train_release/bird/train_bird_8400.wav
#   inflating: s1_train_release/bird/train_bird_8401.wav
#   inflating: s1_train_release/bird/train_bird_8402.wav
#   inflating: s1_train_release/bird/train_bird_8405.wav
#   inflating: s1_train_release/bird/train_bird_8406.wav
#   inflating: s1_train_release/bird/train_bird_8407.wav
#   inflating: s1_train_release/bird/train_bird_8408.wav
#   inflating: s1_train_release/bird/train_bird_8409.wav
#   inflating: s1_train_release/bird/train_bird_8411.wav
#   inflating: s1_train_release/bird/train_bird_8416.wav
#   inflating: s1_train_release/bird/train_bird_8417.wav
#   inflating: s1_train_release/bird/train_bird_8419.wav
#   inflating: s1_train_release/bird/train_bird_8420.wav
#   inflating: s1_train_release/bird/train_bird_8424.wav
#   inflating: s1_train_release/bird/train_bird_8426.wav
#   inflating: s1_train_release/bird/train_bird_8427.wav
#   inflating: s1_train_release/bird/train_bird_8431.wav
#   inflating: s1_train_release/bird/train_bird_8433.wav
#   inflating: s1_train_release/bird/train_bird_8434.wav
#   inflating: s1_train_release/bird/train_bird_8436.wav
#   inflating: s1_train_release/bird/train_bird_8437.wav
#   inflating: s1_train_release/bird/train_bird_8438.wav
#   inflating: s1_train_release/bird/train_bird_8439.wav
#   inflating: s1_train_release/bird/train_bird_8440.wav
#   inflating: s1_train_release/bird/train_bird_8441.wav
#   inflating: s1_train_release/bird/train_bird_8442.wav
#   inflating: s1_train_release/bird/train_bird_8444.wav
#   inflating: s1_train_release/two/train_two_2333.wav
#   inflating: s1_train_release/two/train_two_2335.wav
#   inflating: s1_train_release/two/train_two_2336.wav
#   inflating: s1_train_release/two/train_two_2337.wav
#   inflating: s1_train_release/two/train_two_2339.wav
#   inflating: s1_train_release/two/train_two_2342.wav
#   inflating: s1_train_release/two/train_two_2343.wav
#   inflating: s1_train_release/two/train_two_2349.wav
#   inflating: s1_train_release/two/train_two_2350.wav
#   inflating: s1_train_release/two/train_two_2351.wav
#   inflating: s1_train_release/two/train_two_2353.wav
#   inflating: s1_train_release/two/train_two_2354.wav
#   inflating: s1_train_release/two/train_two_2355.wav
#   inflating: s1_train_release/two/train_two_2358.wav
#   inflating: s1_train_release/two/train_two_2359.wav
#   inflating: s1_train_release/two/train_two_2360.wav
#   inflating: s1_train_release/two/train_two_2361.wav
#   inflating: s1_train_release/two/train_two_2364.wav
#   inflating: s1_train_release/two/train_two_2366.wav
#   inflating: s1_train_release/two/train_two_2367.wav
#   inflating: s1_train_release/two/train_two_2368.wav
#   inflating: s1_train_release/two/train_two_2369.wav
#   inflating: s1_train_release/two/train_two_2370.wav
#   inflating: s1_train_release/two/train_two_2374.wav
#   inflating: s1_train_release/two/train_two_2377.wav
#   inflating: s1_train_release/two/train_two_2378.wav
#   inflating: s1_train_release/two/train_two_2379.wav
#   inflating: s1_train_release/two/train_two_2380.wav
#   inflating: s1_train_release/two/train_two_2384.wav
#   inflating: s1_train_release/two/train_two_2386.wav
#   inflating: s1_train_release/two/train_two_2389.wav
#   inflating: s1_train_release/two/train_two_2390.wav
#   inflating: s1_train_release/two/train_two_2391.wav
#   inflating: s1_train_release/two/train_two_2392.wav
#   inflating: s1_train_release/two/train_two_2393.wav
#   inflating: s1_train_release/two/train_two_2394.wav
#   inflating: s1_train_release/two/train_two_2395.wav
#   inflating: s1_train_release/two/train_two_2396.wav
#   inflating: s1_train_release/two/train_two_2397.wav
#   inflating: s1_train_release/two/train_two_2398.wav
#   inflating: s1_train_release/two/train_two_2399.wav
#   inflating: s1_train_release/two/train_two_2403.wav
#   inflating: s1_train_release/two/train_two_2404.wav
#   inflating: s1_train_release/two/train_two_2405.wav
#   inflating: s1_train_release/two/train_two_2406.wav
#   inflating: s1_train_release/two/train_two_2407.wav
#   inflating: s1_train_release/two/train_two_2408.wav
#   inflating: s1_train_release/two/train_two_2410.wav
#   inflating: s1_train_release/two/train_two_2412.wav
#   inflating: s1_train_release/two/train_two_2414.wav
#   inflating: s1_train_release/two/train_two_2415.wav
#   inflating: s1_train_release/two/train_two_2418.wav
#   inflating: s1_train_release/two/train_two_2420.wav
#   inflating: s1_train_release/two/train_two_2422.wav
#   inflating: s1_train_release/two/train_two_2425.wav
#   inflating: s1_train_release/two/train_two_2426.wav
#   inflating: s1_train_release/two/train_two_2429.wav
#   inflating: s1_train_release/two/train_two_2430.wav
#   inflating: s1_train_release/two/train_two_2431.wav
#   inflating: s1_train_release/two/train_two_2432.wav
#   inflating: s1_train_release/two/train_two_2433.wav
#   inflating: s1_train_release/two/train_two_2434.wav
#   inflating: s1_train_release/two/train_two_2436.wav
#   inflating: s1_train_release/two/train_two_2439.wav
#   inflating: s1_train_release/two/train_two_2441.wav
#   inflating: s1_train_release/two/train_two_2442.wav
#   inflating: s1_train_release/two/train_two_2443.wav
#   inflating: s1_train_release/two/train_two_2444.wav
#   inflating: s1_train_release/two/train_two_2445.wav
#   inflating: s1_train_release/two/train_two_2446.wav
#   inflating: s1_train_release/two/train_two_2449.wav
#    creating: s1_train_release/zero/
#   inflating: s1_train_release/zero/train_zero_4200.wav
#   inflating: s1_train_release/zero/train_zero_4201.wav
#   inflating: s1_train_release/zero/train_zero_4203.wav
#   inflating: s1_train_release/zero/train_zero_4204.wav
#   inflating: s1_train_release/zero/train_zero_4206.wav
#   inflating: s1_train_release/zero/train_zero_4207.wav
#   inflating: s1_train_release/zero/train_zero_4208.wav
#   inflating: s1_train_release/zero/train_zero_4209.wav
#   inflating: s1_train_release/zero/train_zero_4211.wav
#   inflating: s1_train_release/zero/train_zero_4212.wav
#   inflating: s1_train_release/zero/train_zero_4213.wav
#   inflating: s1_train_release/zero/train_zero_4214.wav
#   inflating: s1_train_release/zero/train_zero_4215.wav
#   inflating: s1_train_release/zero/train_zero_4217.wav
#   inflating: s1_train_release/zero/train_zero_4219.wav
#   inflating: s1_train_release/zero/train_zero_4220.wav
#   inflating: s1_train_release/zero/train_zero_4222.wav
#   inflating: s1_train_release/zero/train_zero_4223.wav
#   inflating: s1_train_release/zero/train_zero_4224.wav
#   inflating: s1_train_release/zero/train_zero_4225.wav
#   inflating: s1_train_release/zero/train_zero_4226.wav
#   inflating: s1_train_release/zero/train_zero_4229.wav
#   inflating: s1_train_release/zero/train_zero_4231.wav
#   inflating: s1_train_release/zero/train_zero_4232.wav
#   inflating: s1_train_release/zero/train_zero_4233.wav
#   inflating: s1_train_release/zero/train_zero_4234.wav
#   inflating: s1_train_release/zero/train_zero_4236.wav
#   inflating: s1_train_release/zero/train_zero_4240.wav
#   inflating: s1_train_release/zero/train_zero_4241.wav
#   inflating: s1_train_release/zero/train_zero_4248.wav
#   inflating: s1_train_release/zero/train_zero_4251.wav
#   inflating: s1_train_release/zero/train_zero_4256.wav
#   inflating: s1_train_release/zero/train_zero_4260.wav
#   inflating: s1_train_release/zero/train_zero_4264.wav
#   inflating: s1_train_release/zero/train_zero_4265.wav
#   inflating: s1_train_release/zero/train_zero_4267.wav
#   inflating: s1_train_release/zero/train_zero_4269.wav
#   inflating: s1_train_release/zero/train_zero_4270.wav
#   inflating: s1_train_release/zero/train_zero_4271.wav
#   inflating: s1_train_release/zero/train_zero_4273.wav
#   inflating: s1_train_release/zero/train_zero_4276.wav
#   inflating: s1_train_release/zero/train_zero_4277.wav
#   inflating: s1_train_release/zero/train_zero_4278.wav
#   inflating: s1_train_release/zero/train_zero_4280.wav
#   inflating: s1_train_release/zero/train_zero_4283.wav
#   inflating: s1_train_release/zero/train_zero_4284.wav
#   inflating: s1_train_release/zero/train_zero_4285.wav
#   inflating: s1_train_release/zero/train_zero_4286.wav
#   inflating: s1_train_release/zero/train_zero_4287.wav
#   inflating: s1_train_release/zero/train_zero_4288.wav
#   inflating: s1_train_release/zero/train_zero_4289.wav
#   inflating: s1_train_release/zero/train_zero_4290.wav
#   inflating: s1_train_release/zero/train_zero_4293.wav
#   inflating: s1_train_release/zero/train_zero_4294.wav
#   inflating: s1_train_release/zero/train_zero_4297.wav
#   inflating: s1_train_release/zero/train_zero_4298.wav
#   inflating: s1_train_release/zero/train_zero_4299.wav
#   inflating: s1_train_release/zero/train_zero_4302.wav
#   inflating: s1_train_release/zero/train_zero_4303.wav
#   inflating: s1_train_release/zero/train_zero_4304.wav
#   inflating: s1_train_release/zero/train_zero_4306.wav
#   inflating: s1_train_release/zero/train_zero_4307.wav
#   inflating: s1_train_release/zero/train_zero_4308.wav
#   inflating: s1_train_release/zero/train_zero_4309.wav
#   inflating: s1_train_release/zero/train_zero_4311.wav
#   inflating: s1_train_release/zero/train_zero_4312.wav
#   inflating: s1_train_release/zero/train_zero_4313.wav
#   inflating: s1_train_release/zero/train_zero_4316.wav
#   inflating: s1_train_release/zero/train_zero_4317.wav
#   inflating: s1_train_release/zero/train_zero_4318.wav
#   inflating: s1_train_release/zero/train_zero_4319.wav
#   inflating: s1_train_release/zero/train_zero_4320.wav
#   inflating: s1_train_release/zero/train_zero_4322.wav
#   inflating: s1_train_release/zero/train_zero_4325.wav
#   inflating: s1_train_release/zero/train_zero_4328.wav
#   inflating: s1_train_release/zero/train_zero_4329.wav
#   inflating: s1_train_release/zero/train_zero_4330.wav
#   inflating: s1_train_release/zero/train_zero_4331.wav
#   inflating: s1_train_release/zero/train_zero_4332.wav
#   inflating: s1_train_release/zero/train_zero_4333.wav
#   inflating: s1_train_release/zero/train_zero_4334.wav
#   inflating: s1_train_release/zero/train_zero_4336.wav
#   inflating: s1_train_release/zero/train_zero_4338.wav
#   inflating: s1_train_release/zero/train_zero_4339.wav
#   inflating: s1_train_release/zero/train_zero_4340.wav
#   inflating: s1_train_release/zero/train_zero_4341.wav
#   inflating: s1_train_release/zero/train_zero_4342.wav
#   inflating: s1_train_release/zero/train_zero_4343.wav
#   inflating: s1_train_release/zero/train_zero_4346.wav
#   inflating: s1_train_release/zero/train_zero_4347.wav
#   inflating: s1_train_release/zero/train_zero_4350.wav
#   inflating: s1_train_release/zero/train_zero_4351.wav
#   inflating: s1_train_release/zero/train_zero_4352.wav
#   inflating: s1_train_release/zero/train_zero_4354.wav
#   inflating: s1_train_release/zero/train_zero_4355.wav
#   inflating: s1_train_release/zero/train_zero_4356.wav
#   inflating: s1_train_release/zero/train_zero_4357.wav
#   inflating: s1_train_release/zero/train_zero_4358.wav
#   inflating: s1_train_release/zero/train_zero_4360.wav
#   inflating: s1_train_release/zero/train_zero_4365.wav
#   inflating: s1_train_release/zero/train_zero_4369.wav
#   inflating: s1_train_release/zero/train_zero_4377.wav
#   inflating: s1_train_release/zero/train_zero_4378.wav
#   inflating: s1_train_release/zero/train_zero_4379.wav
#   inflating: s1_train_release/zero/train_zero_4380.wav
#   inflating: s1_train_release/zero/train_zero_4383.wav
#   inflating: s1_train_release/zero/train_zero_4384.wav
#   inflating: s1_train_release/zero/train_zero_4386.wav
#   inflating: s1_train_release/zero/train_zero_4389.wav
#   inflating: s1_train_release/zero/train_zero_4391.wav
#   inflating: s1_train_release/zero/train_zero_4392.wav
#   inflating: s1_train_release/zero/train_zero_4393.wav
#   inflating: s1_train_release/zero/train_zero_4394.wav
#   inflating: s1_train_release/zero/train_zero_4395.wav
#   inflating: s1_train_release/zero/train_zero_4396.wav
#   inflating: s1_train_release/zero/train_zero_4398.wav
#   inflating: s1_train_release/zero/train_zero_4400.wav
#   inflating: s1_train_release/zero/train_zero_4402.wav
#   inflating: s1_train_release/zero/train_zero_4403.wav
#   inflating: s1_train_release/zero/train_zero_4404.wav
#   inflating: s1_train_release/zero/train_zero_4405.wav
#   inflating: s1_train_release/zero/train_zero_4406.wav
#   inflating: s1_train_release/zero/train_zero_4407.wav
#   inflating: s1_train_release/zero/train_zero_4408.wav
#   inflating: s1_train_release/zero/train_zero_4409.wav
#   inflating: s1_train_release/zero/train_zero_4411.wav
#   inflating: s1_train_release/zero/train_zero_4412.wav
#   inflating: s1_train_release/zero/train_zero_4413.wav
#   inflating: s1_train_release/zero/train_zero_4414.wav
#   inflating: s1_train_release/zero/train_zero_4415.wav
#   inflating: s1_train_release/zero/train_zero_4417.wav
#   inflating: s1_train_release/zero/train_zero_4418.wav
#   inflating: s1_train_release/zero/train_zero_4420.wav
#   inflating: s1_train_release/zero/train_zero_4422.wav
#   inflating: s1_train_release/zero/train_zero_4424.wav
#   inflating: s1_train_release/zero/train_zero_4425.wav
#   inflating: s1_train_release/zero/train_zero_4428.wav
#   inflating: s1_train_release/zero/train_zero_4431.wav
#   inflating: s1_train_release/zero/train_zero_4432.wav
#   inflating: s1_train_release/zero/train_zero_4433.wav
#   inflating: s1_train_release/zero/train_zero_4434.wav
#   inflating: s1_train_release/zero/train_zero_4435.wav
#   inflating: s1_train_release/zero/train_zero_4436.wav
#   inflating: s1_train_release/zero/train_zero_4439.wav
#   inflating: s1_train_release/zero/train_zero_4442.wav
#   inflating: s1_train_release/zero/train_zero_4444.wav
#   inflating: s1_train_release/zero/train_zero_4448.wav
#   inflating: s1_train_release/zero/train_zero_4449.wav
#   inflating: s1_train_release/zero/train_zero_4453.wav
#   inflating: s1_train_release/zero/train_zero_4455.wav
#   inflating: s1_train_release/zero/train_zero_4456.wav
#   inflating: s1_train_release/zero/train_zero_4457.wav
#   inflating: s1_train_release/zero/train_zero_4459.wav
#   inflating: s1_train_release/zero/train_zero_4460.wav
#   inflating: s1_train_release/zero/train_zero_4461.wav
#   inflating: s1_train_release/zero/train_zero_4464.wav
#   inflating: s1_train_release/zero/train_zero_4465.wav
#   inflating: s1_train_release/zero/train_zero_4467.wav
#   inflating: s1_train_release/zero/train_zero_4468.wav
#   inflating: s1_train_release/zero/train_zero_4473.wav
#   inflating: s1_train_release/zero/train_zero_4474.wav
#   inflating: s1_train_release/zero/train_zero_4475.wav
#   inflating: s1_train_release/zero/train_zero_4483.wav
#   inflating: s1_train_release/zero/train_zero_4484.wav
#   inflating: s1_train_release/zero/train_zero_4487.wav
#   inflating: s1_train_release/zero/train_zero_4488.wav
#   inflating: s1_train_release/zero/train_zero_4489.wav
#   inflating: s1_train_release/zero/train_zero_4492.wav
#   inflating: s1_train_release/zero/train_zero_4498.wav
#   inflating: s1_train_release/zero/train_zero_4500.wav
#   inflating: s1_train_release/zero/train_zero_4506.wav
#   inflating: s1_train_release/zero/train_zero_4508.wav
#   inflating: s1_train_release/zero/train_zero_4509.wav
#   inflating: s1_train_release/zero/train_zero_4510.wav
#   inflating: s1_train_release/zero/train_zero_4511.wav
#   inflating: s1_train_release/zero/train_zero_4512.wav
#   inflating: s1_train_release/zero/train_zero_4514.wav
#   inflating: s1_train_release/zero/train_zero_4517.wav
#   inflating: s1_train_release/zero/train_zero_4518.wav
#   inflating: s1_train_release/zero/train_zero_4521.wav
#   inflating: s1_train_release/zero/train_zero_4522.wav
#   inflating: s1_train_release/zero/train_zero_4523.wav
#   inflating: s1_train_release/zero/train_zero_4524.wav
#   inflating: s1_train_release/zero/train_zero_4525.wav
#   inflating: s1_train_release/zero/train_zero_4526.wav
#   inflating: s1_train_release/zero/train_zero_4527.wav
#   inflating: s1_train_release/zero/train_zero_4528.wav
#   inflating: s1_train_release/zero/train_zero_4529.wav
#   inflating: s1_train_release/zero/train_zero_4530.wav
#   inflating: s1_train_release/zero/train_zero_4531.wav
#   inflating: s1_train_release/zero/train_zero_4532.wav
#   inflating: s1_train_release/zero/train_zero_4533.wav
#   inflating: s1_train_release/zero/train_zero_4534.wav
#   inflating: s1_train_release/zero/train_zero_4536.wav
#   inflating: s1_train_release/zero/train_zero_4537.wav
#   inflating: s1_train_release/zero/train_zero_4542.wav
#   inflating: s1_train_release/zero/train_zero_4543.wav
#   inflating: s1_train_release/zero/train_zero_4545.wav
#   inflating: s1_train_release/zero/train_zero_4546.wav
#   inflating: s1_train_release/zero/train_zero_4548.wav

# %%
class CustomSpeechDataset(torch.utils.data.Dataset):
  def __init__(self, path, typ='train', transforms=None):

    assert typ == 'train' or typ == 'test', 'typ must be either "train" or "test"'

    self.typ = typ
    self.transforms = transforms
    self.targets = []

    if self.typ == 'train':
      self.class_names = sorted(os.listdir(path))
      num_classes = len(self.class_names)

      for class_idx, class_name in enumerate(self.class_names):
        class_dirx = os.path.join(path, class_name)
        wav_list = os.listdir(class_dirx)

        for wav_file in wav_list:
          self.targets.append({
              'filename': wav_file,
              'path': os.path.join(class_dirx, wav_file),
              'class': class_name
          })

    if self.typ == 'test':
      wav_list = os.listdir(path)
      for wav_file in wav_list:
        self.targets.append({
            'filename': wav_file,
            'path': os.path.join(path, wav_file)
        })
  
  def __len__(self):
    return len(self.targets)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx.tolist()

    signal, sr = torchaudio.load(self.targets[idx]['path'], normalization=True)
    filename = self.targets[idx]['filename']

    if self.transforms:
      for transform in self.transforms:
        signal = transform(signal)

    if self.typ == 'train':
      clx_name = self.targets[idx]['class']
      return filename, signal, sr, clx_name
    
    elif self.typ == 'test':
      return filename, signal, sr

# %%
full_dataset = CustomSpeechDataset(path='s1_train_release', typ='train')
train_size = int(len(full_dataset)*0.8)
valid_size = len(full_dataset) - train_size
train_set, valid_set = torch.utils.data.random_split(full_dataset, [train_size, valid_size])

# %%
print(train_size, valid_size)
# Out:
# 2080 520

# %%
labels = full_dataset.class_names
print(labels)
# Out:
# ['bird', 'eight', 'falcon', 'five', 'four', 'nine', 'one', 'seven', 'six', 'snake', 'three', 'two', 'zero']

# %%
labels_to_indices = {}
for idx, l in enumerate(labels):
  labels_to_indices[l] = idx

# %%
# Looking at 1st item from the training set
filename, waveform, sample_rate, label_id = train_set[0]

# %%
print("Shape of waveform: {}".format(waveform.size()))
print("Sample rate of waveform: {}".format(sample_rate))

# Let's plot the waveform using matplotlib
# We observe that the main audio activity happens at the later end of the clip
plt.plot(waveform.t().numpy());
# Out:
# Shape of waveform: torch.Size([1, 16000])
# Sample rate of waveform: 16000

# %%
# let's play the audio clip and hear it for ourselves!
ipd.Audio(waveform.numpy(), rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Constant Sample Lengths
# In order to insert our features into a model, we have to ensure that the features are of the same size. Below, we see that the sample length varies across the audio clips.
#
# Let's pad the audio clips to a maximum sample length of 16000. (16000 sample length is equal to 1 second at 16,000 Hz sampling rate)
# We will pad audio clips which are less than 1 second in length, with parts of itself.

# %%
audio_lens = []
for i in range(len(train_set)):
  audio_lens.append(train_set[i][1].size(1))

print('Max Sample Length:', max(audio_lens))
print('Min Sample Length:', min(audio_lens))
# Out:
# Max Sample Length: 16000
# Min Sample Length: 16000

# %%
class PadAudio(torch.nn.Module):
  def __init__(self, req_length = 16000):
    super().__init__()
    self.req_length = req_length

  def forward(self, waveform):
    while waveform.size(1) < self.req_length:
      waveform = torch.cat((waveform, waveform[:, :self.req_length - waveform.size(1)]), axis=1)
    return waveform

# let's set up a list of transformations we are going to apply to the waveforms
transformations = []
transformations.append(PadAudio())

# %% [markdown]
# ## Features
# In this classification example, instead of using the raw waveform of the audio clips, we will craft handmade audio features known as melspectrograms instead.

# %%
from torchaudio.transforms import MelSpectrogram

# We define our own log transformation here
class LogMelTransform(torch.nn.Module):

    def __init__(self, log_offset = 1e-6):
        super().__init__()
        self.log_offset = log_offset

    def forward(self, melspectrogram):
        return torch.log(melspectrogram + self.log_offset)

# Let's append these new transformations
transformations.append(MelSpectrogram(sample_rate = 16000, n_mels = 128))
transformations.append(LogMelTransform())

# %% [markdown]
# ## Data Augmentation
#
# We will do a simple data augmentation process in order to increase the variations in our dataset.
#
# In the audio domain, the augmentation technique known as [SpecAugment](https://arxiv.org/abs/1904.08779) is often used. It makes use of 3 steps:
# - Time Warp (warps the spectrogram to the left or right)
# - Frequency Masking (randomly masks a range of frequencies)
# - Time Masking (randomly masks a range of time)

# %%
from torchaudio.transforms import TimeMasking, FrequencyMasking

eval_transformations = transformations.copy()

# Let's extend the list of transformations with the augmentations
transformations.append(TimeMasking(time_mask_param = 10)) # a maximum of 10 time steps will be masked
transformations.append(FrequencyMasking(freq_mask_param = 3)) # maximum of 3 freq channels will be masked

# %% [markdown]
# ## Data Loaders
#
# Let's now set up our data loaders so that we can streamline the batch loading of data for our model training later on.

# %%
BATCH_SIZE = 32
NUM_WORKERS = 4
PIN_MEMORY = True if device == 'cuda' else False

def train_collate_fn(batch):

    # A data tuple has the form:
    # filename, waveform, sample_rate, label

    tensors, targets, filenames = [], [], []

    # Gather in lists, and encode labels as indices
    for filename, waveform, sample_rate, label in batch:
        # apply transformations
        for transform in transformations:
            waveform = transform(waveform)
        waveform = waveform.squeeze().T
        tensors += [waveform]
        targets += [labels_to_indices[label]]
        filenames += [filename]

    # Group the list of tensors into a batched tensor
    tensors = torch.stack(tensors)
    targets = torch.LongTensor(targets)

    return (tensors, targets, filenames)

def eval_collate_fn(batch):

    # A data tuple has the form:
    # filename, waveform, sample_rate, label

    tensors, targets, filenames = [], [], []

    # Gather in lists, and encode labels as indices
    for filename, waveform, sample_rate, label in batch:
        # apply transformations
        for transform in eval_transformations:
            waveform = transform(waveform)
        waveform = waveform.squeeze().T
        tensors += [waveform]
        targets += [labels_to_indices[label]]
        filenames += [filename]

    # Group the list of tensors into a batched tensor
    tensors = torch.stack(tensors)
    targets = torch.LongTensor(targets)
    filenames += [filename]

    return (tensors, targets, filenames)

train_loader = torch.utils.data.DataLoader(
    train_set,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=False,
    collate_fn=train_collate_fn,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
)

valid_loader = torch.utils.data.DataLoader(
    valid_set,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    collate_fn=eval_collate_fn,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
)

# %% [markdown]
# ## Setting up the Model
#
# In this speech classification example, we will make use of a Long-Short-Term Memory Recurrent Neural Network (LSTM-RNN).

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, device, classes=None):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.device = device
        self.classes = classes

    def forward(self, x):
        # Set initial hidden and cell states
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(self.device) 
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(self.device) 
        
        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))  # shape = (batch_size, seq_length, hidden_size)
        
        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

    def predict(self, x):
        '''Predict one label from one sample's features'''
        # x: feature from a sample, LxN
        #   L is length of sequency
        #   N is feature dimension
        x = torch.tensor(x[np.newaxis, :], dtype=torch.float32)
        x = x.to(self.device)
        outputs = self.forward(x)
        _, predicted = torch.max(outputs.data, 1)
        predicted_index = predicted.item()
        return predicted_index

# %%
# initialize the model class
model = RNN(input_size=128, hidden_size=128, num_layers=2, num_classes=len(labels), device=device, classes=labels).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
optimizer.zero_grad()
num_epochs = 50

# %%
for epoch in range(1,num_epochs+1):

  # training steps
  model.train()
  count_correct, count_total = 0, 0
  for idx, (features, targets, filenames) in enumerate(train_loader):

    features = features.to(device)
    targets = targets.to(device)

    # forward pass
    outputs = model(features)
    loss = criterion(outputs, targets)

    # backward pass
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    # training results
    _, argmax = torch.max(outputs, 1)
    count_correct += (targets == argmax.squeeze()).sum().item()
    count_total += targets.size(0)

  train_acc = count_correct / count_total
  
  # evaluation steps
  model.eval()
  count_correct, count_total = 0, 0
  with torch.no_grad():
    for idx, (features, targets, filenames) in enumerate(valid_loader):

      features = features.to(device)
      targets = targets.to(device)

      # forward pass
      val_outputs = model(features)
      val_loss = criterion(val_outputs, targets)

      # validation results
      _, argmax = torch.max(val_outputs, 1)
      count_correct += (targets == argmax.squeeze()).sum().item()
      count_total += targets.size(0)

  # print results
  valid_acc = count_correct / count_total
  print('Epoch [{}/{}], Train loss = {:.4f}, Train accuracy = {:.2f}, Valid loss = {:.4f}, Valid accuracy = {:.2f}' 
        .format(epoch, num_epochs, loss.item(), 100*train_acc, val_loss.item(), 100*valid_acc))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-f4ec4c3ddbe6> in <module>()
#       4   model.train()
#       5   count_correct, count_total = 0, 0
# ----> 6   for idx, (features, targets, filenames) in enumerate(train_loader):
#       7
#       8     features = features.to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1083             else:
#    1084                 del self._task_info[idx]
# -> 1085                 return self._process_data(data)
#    1086
#    1087     def _try_put_index(self):
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1109         self._try_put_index()
#    1110         if isinstance(data, ExceptionWrapper):
# -> 1111             data.reraise()
#    1112         return data
#    1113
#
# /usr/local/lib/python3.7/dist-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/worker.py", line 198, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py", line 47, in fetch
#     return self.collate_fn(data)
#   File "<ipython-input-23-93dc5349535a>", line 16, in train_collate_fn
#     waveform = transform(waveform)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torchaudio/transforms.py", line 434, in forward
#     specgram = self.spectrogram(waveform)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torchaudio/transforms.py", line 84, in forward
#     self.win_length, self.power, self.normalized)
#   File "/usr/local/lib/python3.7/dist-packages/torchaudio/functional.py", line 88, in spectrogram
#     waveform, n_fft, hop_length, win_length, window, True, "reflect", False, True
#   File "/usr/local/lib/python3.7/dist-packages/torch/functional.py", line 513, in stft
#     input = F.pad(input.view(extended_shape), (pad, pad), pad_mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py", line 3559, in _pad
#     return torch._C._nn.reflection_pad1d(input, pad)
# RuntimeError: Argument #4: Padding size should be less than the corresponding input dimension, but got: padding (200, 200) at dimension 2 of input [1, 128, 81]

# %%
torch.save(model.state_dict(), 'speech_classification_lstm.pt')

# %% [markdown]
# ## Test Set

# %%
# !gdown --id 1AvP49xengGjnFTG209AgvAGj-by8WGSi
# !unzip -q -o s1_test.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1AvP49xengGjnFTG209AgvAGj-by8WGSi
# To: /content/s1_test.zip
# 12.3MB [00:00, 108MB/s]

# %%
# Initialise dataset object for test set
test_set = CustomSpeechDataset(path='s1_test', typ='test')

# %%
# define test collate function and set up test loader

def test_collate_fn(batch):

    # A data tuple has the form:
    # filename, waveform, sample_rate

    tensors, filenames = [], []

    # Gather in lists
    for filename, waveform, sample_rate in batch:
        # apply transformations
        for transform in eval_transformations:
            waveform = transform(waveform)
        waveform = waveform.squeeze().T
        tensors += [waveform]
        filenames += [filename]

    # Group the list of tensors into a batched tensor
    tensors = torch.stack(tensors)

    return (tensors, filenames)

test_loader = torch.utils.data.DataLoader(
    test_set,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    collate_fn=test_collate_fn,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
)

# %%
# pass test set through the RNN model
model.eval()
pred_list, filename_list = [], []
with torch.no_grad():
  for idx, (features, filenames) in enumerate(test_loader):

    features = features.to(device)

    # forward pass
    outputs = model(features)

    # validation results
    _, argmax = torch.max(outputs, 1)
    pred_list += argmax.cpu().tolist()
    filename_list += filenames

# %% [markdown]
# ## Submission of Results
# Submission csv file should contain only 2 columns for filename and label, in that order. The file should be sorted by filename, and exclude headers.
#
# Refer to **sample_submission.csv** for an example.

# %%
result_tuple = list(zip(filename_list, pred_list))
submission = pd.DataFrame(result_tuple, columns=['filename', 'pred'])
submission = submission.sort_values('filename').reset_index(drop=True)
submission['label'] = submission['pred'].apply(lambda x: labels[x])

# %%
submission[['filename', 'label']].head()
submission[['filename', 'label']].to_csv('submission.csv', header=None, index=None)
